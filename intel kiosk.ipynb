# %%
import json

feature_map = {
    "existing_features": [
        "Walk-in Appointment Booking",
        "UPI/Card Payments",
        "Indoor Patient Status",
        "Vitals Monitoring"
    ],
    "proposed_features": [
        "Face ID Check-in (like DigiYatri)",
        "Interoperable EHRs (ABDM integration)",
        "Federated Learning Capability",
        "AI-powered Multilingual Transcription",
        "Remote Doctor Consultation",
        "Preliminary Diagnosis & Treatment Suggestion"
    ],
    "hardware_requirements": {
        "CPU": "Intel 12th Gen i5/i7",
        "RAM": "16GB",
        "Storage": "512GB SSD",
        "Touch Display": "24-inch capacitive",
        "Connectivity": "4G/5G, Wi-Fi, Ethernet"
    }
}
print(json.dumps(feature_map, indent=2))
gtm_blueprint = {
    "target_segments": ["Rural Clinics", "Tier-2 Hospitals", "Ayushman Arogya Mandirs"],
    "partners": {
        "HW OEM": ["HP", "Lenovo", "Dell"],
        "ISVs": ["HealthPlix", "Practo", "1mg"],
        "SIs": ["Tata Consultancy Services", "Wipro Health"]
    },
    "marketing_strategy": [
        "Pilot deployments in Karnataka & West Bengal",
        "Awareness through government portals",
        "Demo sessions at healthcare events"
    ],
    "support_mechanism": [
        "24x7 Remote Support",
        "On-site Maintenance",
        "Training for Hospital Staff"
    ]
}
print(json.dumps(feature_map, indent=2))
mrd = {
    "product_vision": "AI-powered self-service kiosks for healthcare",
    "competitive_landscape": [
        "Current Kiosks (limited to payment & vitals)",
        "No federated learning or multilingual AI in rural healthcare"
    ],
    "business_opportunity": "Capture underserved Tier 2/3 India with $600B healthcare market",
    "revenue_streams": ["Hardware Sales", "Cloud Subscription", "AI Services Licensing"],
    "key_features": [
        "Face ID-based registration",
        "EHR integration with ABDM",
        "AI diagnosis with Indian dialect support",
        "Teleconsultation via kiosk",
        "Federated Learning at Edge"
    ]
}
print(json.dumps(mrd, indent=2))
import random

def get_vitals():
    return {
        "temperature": round(random.uniform(97.5, 99.5), 1),
        "bp_systolic": random.randint(110, 130),
        "bp_diastolic": random.randint(70, 90),
        "spo2": random.randint(95, 100),
        "pulse": random.randint(60, 100)
    }

def ai_diagnosis(vitals):
    if vitals["spo2"] < 94:
        return "Possible hypoxia detected. Suggest oxygen therapy."
    elif vitals["bp_systolic"] > 130:
        return "High BP - Suggest physician consult for hypertension."
    else:
        return "Vitals normal. No urgent condition detected."

v = get_vitals()
print("Vitals:", v)
print("Diagnosis:", ai_diagnosis(v))



# Import the transliteration module
from indic_transliteration.sanscript import transliterate
from indic_transliteration.sanscript import ITRANS, DEVANAGARI, KANNADA, TAMIL, TELUGU

# Input medical text in English (ITRANS style)
input_text_itrans = "Patient has high blood pressure and low oxygen level"

# Transliterate into different Indian scripts
hindi_output = transliterate(input_text_itrans, ITRANS, DEVANAGARI)
kannada_output = transliterate(input_text_itrans, ITRANS, KANNADA)
tamil_output = transliterate(input_text_itrans, ITRANS, TAMIL)
telugu_output = transliterate(input_text_itrans, ITRANS, TELUGU)

# Print results
print("🗣️ English Medical Input (ITRANS Style):", input_text_itrans)
print("\n📌 Hindi Script (Devanagari):", hindi_output)
print("📌 Kannada Script:", kannada_output)
print("📌 Tamil Script:", tamil_output)
print("📌 Telugu Script:", telugu_output)
# Out:
# {
#   "existing_features": [
#     "Walk-in Appointment Booking",
#     "UPI/Card Payments",
#     "Indoor Patient Status",
#     "Vitals Monitoring"
#   ],
#   "proposed_features": [
#     "Face ID Check-in (like DigiYatri)",
#     "Interoperable EHRs (ABDM integration)",
#     "Federated Learning Capability",
#     "AI-powered Multilingual Transcription",
#     "Remote Doctor Consultation",
#     "Preliminary Diagnosis & Treatment Suggestion"
#   ],
#   "hardware_requirements": {
#     "CPU": "Intel 12th Gen i5/i7",
#     "RAM": "16GB",
#     "Storage": "512GB SSD",
#     "Touch Display": "24-inch capacitive",
#     "Connectivity": "4G/5G, Wi-Fi, Ethernet"
#   }
# }
# {
#   "existing_features": [
#     "Walk-in Appointment Booking",
#     "UPI/Card Payments",
#     "Indoor Patient Status",
#     "Vitals Monitoring"
#   ],
#   "proposed_features": [
#     "Face ID Check-in (like DigiYatri)",
#     "Interoperable EHRs (ABDM integration)",
#     "Federated Learning Capability",
#     "AI-powered Multilingual Transcription",
#     "Remote Doctor Consultation",
#     "Preliminary Diagnosis & Treatment Suggestion"
#   ],
#   "hardware_requirements": {
#     "CPU": "Intel 12th Gen i5/i7",
#     "RAM": "16GB",
#     "Storage": "512GB SSD",
#     "Touch Display": "24-inch capacitive",
#     "Connectivity": "4G/5G, Wi-Fi, Ethernet"
#   }
# }
# {
#   "product_vision": "AI-powered self-service kiosks for healthcare",
#   "competitive_landscape": [
#     "Current Kiosks (limited to payment & vitals)",
#     "No federated learning or multilingual AI in rural healthcare"
#   ],
#   "business_opportunity": "Capture underserved Tier 2/3 India with $600B healthcare market",
#   "revenue_streams": [
#     "Hardware Sales",
#     "Cloud Subscription",
#     "AI Services Licensing"
#   ],
#   "key_features": [
#     "Face ID-based registration",
#     "EHR integration with ABDM",
#     "AI diagnosis with Indian dialect support",
#     "Teleconsultation via kiosk",
#     "Federated Learning at Edge"
#   ]
# }
# Vitals: {'temperature': 97.7, 'bp_systolic': 118, 'bp_diastolic': 77, 'spo2': 96, 'pulse': 64}
# Diagnosis: Vitals normal. No urgent condition detected.
# 🗣️ English Medical Input (ITRANS Style): Patient has high blood pressure and low oxygen level
#
# 📌 Hindi Script (Devanagari): Pअतिएन्त् हस् हिघ् ब्लूद् प्रेस्सुरे अन्द् लोव् ओक्ष्य्गेन् लेवेल्
# 📌 Kannada Script: Pಅತಿಏನ್ತ್ ಹಸ್ ಹಿಘ್ ಬ್ಲೂದ್ ಪ್ರೇಸ್ಸುರೇ ಅನ್ದ್ ಲೋವ್ ಓಕ್ಷ್ಯ್ಗೇನ್ ಲೇವೇಲ್
# 📌 Tamil Script: Pஅதிஏந்த் ஹஸ் ஹிக் ப்லூத் ப்ரேஸ்ஸுரே அந்த் லோவ் ஓக்ஷ்ய்கேந் லேவேல்
# 📌 Telugu Script: Pఅతిఏన్త్ హస్ హిఘ్ బ్లూద్ ప్రేస్సురే అన్ద్ లోవ్ ఓక్ష్య్గేన్ లేవేల్
