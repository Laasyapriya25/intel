# %%
# !pip install googletrans==4.0.0-rc1
import random
from googletrans import Translator

# Initialize Google Translate
translator = Translator()

# Languages for translation
languages = {
    "hi": "Hindi",
    "kn": "Kannada",
    "ta": "Tamil",
    "te": "Telugu"
}

# Generate random vitals
def get_vitals():
    return {
        "temperature": round(random.uniform(97.5, 99.5), 1),
        "bp_systolic": random.randint(110, 140),
        "bp_diastolic": random.randint(70, 90),
        "spo2": random.randint(90, 100),
        "pulse": random.randint(60, 100)
    }

# Simple AI diagnosis logic
def ai_diagnosis(vitals):
    if vitals["spo2"] < 94:
        return "Possible hypoxia detected. Suggest oxygen therapy."
    elif vitals["bp_systolic"] > 130:
        return "High BP - Suggest physician consult for hypertension."
    else:
        return "Vitals normal. No urgent condition detected."

# Get vitals and diagnosis
vitals = get_vitals()
diagnosis_en = ai_diagnosis(vitals)

# Print Vitals and Diagnosis in English
print("\n🩺 Vitals:", vitals)
print("💡 Diagnosis (English):", diagnosis_en)

# Translate diagnosis into multiple languages
print("\n🌐 Translated Diagnosis:")
for lang_code, lang_name in languages.items():
    try:
        translated = translator.translate(diagnosis_en, dest=lang_code).text
        print(f"{lang_name}: {translated}")
    except Exception as e:
        print(f"{lang_name}: [Translation Error - {e}]")
# Out:
# 🩺 Vitals: {'temperature': 98.4, 'bp_systolic': 110, 'bp_diastolic': 79, 'spo2': 99, 'pulse': 65}
# 💡 Diagnosis (English): Vitals normal. No urgent condition detected.
#
# 🌐 Translated Diagnosis:
# Hindi: सामान्य सामान्य।कोई तत्काल स्थिति का पता नहीं चला।
# Kannada: ಜೀವಕೋಶಗಳು ಸಾಮಾನ್ಯ.ಯಾವುದೇ ತುರ್ತು ಸ್ಥಿತಿ ಪತ್ತೆಯಾಗಿಲ್ಲ.
# Tamil: உயிரணுக்கள் இயல்பானவை.அவசர நிலை எதுவும் கண்டறியப்படவில்லை.
# Telugu: ప్రాణాధారాలు సాధారణం.అత్యవసర పరిస్థితి కనుగొనబడలేదు.

# %%
import json

feature_map = {
    "existing_features": [
        "Walk-in Appointment Booking",
        "UPI/Card Payments",
        "Indoor Patient Status",
        "Vitals Monitoring"
    ],
    "proposed_features": [
        "Face ID Check-in (like DigiYatri)",
        "Interoperable EHRs (ABDM integration)",
        "Federated Learning Capability",
        "AI-powered Multilingual Transcription",
        "Remote Doctor Consultation",
        "Preliminary Diagnosis & Treatment Suggestion"
    ],
    "hardware_requirements": {
        "CPU": "Intel 12th Gen i5/i7",
        "RAM": "16GB",
        "Storage": "512GB SSD",
        "Touch Display": "24-inch capacitive",
        "Connectivity": "4G/5G, Wi-Fi, Ethernet"
    }
}
print(json.dumps(feature_map, indent=2))
gtm_blueprint = {
    "target_segments": ["Rural Clinics", "Tier-2 Hospitals", "Ayushman Arogya Mandirs"],
    "partners": {
        "HW OEM": ["HP", "Lenovo", "Dell"],
        "ISVs": ["HealthPlix", "Practo", "1mg"],
        "SIs": ["Tata Consultancy Services", "Wipro Health"]
    },
    "marketing_strategy": [
        "Pilot deployments in Karnataka & West Bengal",
        "Awareness through government portals",
        "Demo sessions at healthcare events"
    ],
    "support_mechanism": [
        "24x7 Remote Support",
        "On-site Maintenance",
        "Training for Hospital Staff"
    ]
}
print(json.dumps(feature_map, indent=2))
mrd = {
    "product_vision": "AI-powered self-service kiosks for healthcare",
    "competitive_landscape": [
        "Current Kiosks (limited to payment & vitals)",
        "No federated learning or multilingual AI in rural healthcare"
    ],
    "business_opportunity": "Capture underserved Tier 2/3 India with $600B healthcare market",
    "revenue_streams": ["Hardware Sales", "Cloud Subscription", "AI Services Licensing"],
    "key_features": [
        "Face ID-based registration",
        "EHR integration with ABDM",
        "AI diagnosis with Indian dialect support",
        "Teleconsultation via kiosk",
        "Federated Learning at Edge"
    ]
}
print(json.dumps(mrd, indent=2))
import random

def get_vitals():
    return {
        "temperature": round(random.uniform(97.5, 99.5), 1),
        "bp_systolic": random.randint(110, 130),
        "bp_diastolic": random.randint(70, 90),
        "spo2": random.randint(95, 100),
        "pulse": random.randint(60, 100)
    }

def ai_diagnosis(vitals):
    if vitals["spo2"] < 94:
        return "Possible hypoxia detected. Suggest oxygen therapy."
    elif vitals["bp_systolic"] > 130:
        return "High BP - Suggest physician consult for hypertension."
    else:
        return "Vitals normal. No urgent condition detected."

v = get_vitals()
print("Vitals:", v)
print("Diagnosis:", ai_diagnosis(v))



# !pip install googletrans==4.0.0-rc1
import random
from googletrans import Translator

# Initialize Google Translate
translator = Translator()

# Languages for translation
languages = {
    "hi": "Hindi",
    "kn": "Kannada",
    "ta": "Tamil",
    "te": "Telugu"
}

# Generate random vitals
def get_vitals():
    return {
        "temperature": round(random.uniform(97.5, 99.5), 1),
        "bp_systolic": random.randint(110, 140),
        "bp_diastolic": random.randint(70, 90),
        "spo2": random.randint(90, 100),
        "pulse": random.randint(60, 100)
    }

# Simple AI diagnosis logic
def ai_diagnosis(vitals):
    if vitals["spo2"] < 94:
        return "Possible hypoxia detected. Suggest oxygen therapy."
    elif vitals["bp_systolic"] > 130:
        return "High BP - Suggest physician consult for hypertension."
    else:
        return "Vitals normal. No urgent condition detected."

# Get vitals and diagnosis
vitals = get_vitals()
diagnosis_en = ai_diagnosis(vitals)

# Print Vitals and Diagnosis in English
print("\n🩺 Vitals:", vitals)
print("💡 Diagnosis (English):", diagnosis_en)

# Translate diagnosis into multiple languages
print("\n🌐 Translated Diagnosis:")
for lang_code, lang_name in languages.items():
    try:
        translated = translator.translate(diagnosis_en, dest=lang_code).text
        print(f"{lang_name}: {translated}")
    except Exception as e:
        print(f"{lang_name}: [Translation Error - {e}]")
# Out:
# {
#   "existing_features": [
#     "Walk-in Appointment Booking",
#     "UPI/Card Payments",
#     "Indoor Patient Status",
#     "Vitals Monitoring"
#   ],
#   "proposed_features": [
#     "Face ID Check-in (like DigiYatri)",
#     "Interoperable EHRs (ABDM integration)",
#     "Federated Learning Capability",
#     "AI-powered Multilingual Transcription",
#     "Remote Doctor Consultation",
#     "Preliminary Diagnosis & Treatment Suggestion"
#   ],
#   "hardware_requirements": {
#     "CPU": "Intel 12th Gen i5/i7",
#     "RAM": "16GB",
#     "Storage": "512GB SSD",
#     "Touch Display": "24-inch capacitive",
#     "Connectivity": "4G/5G, Wi-Fi, Ethernet"
#   }
# }
# {
#   "existing_features": [
#     "Walk-in Appointment Booking",
#     "UPI/Card Payments",
#     "Indoor Patient Status",
#     "Vitals Monitoring"
#   ],
#   "proposed_features": [
#     "Face ID Check-in (like DigiYatri)",
#     "Interoperable EHRs (ABDM integration)",
#     "Federated Learning Capability",
# ...
